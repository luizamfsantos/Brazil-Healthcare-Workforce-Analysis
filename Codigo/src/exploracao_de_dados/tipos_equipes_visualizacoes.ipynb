# %% [markdown]
# # import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # load data

# %%
path = '../../../Dados/Processado/Equipes_Saude/totais/2007-2023_tipos_equipe.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#                                       Tipo da Equipe  2007-04-01  2007-05-01  \
# 0                01 ESF - EQUIPE DE SAUDE DA FAMILIA        8721       10004
# 1            02 ESFSB_M1 - ESF COM SAUDE BUCAL - M I        8590       10992
# 2           03 ESFSB_M2 - ESF COM SAUDE BUCAL - M II         763         866
# 3  04 EACS - EQUIPE DE AGENTES COMUNITARIOS DE SAUDE        1886        2294
# 4  05 EPEN - EQUIPE DE AT. SAUDE SIST. PENITENCIARIO          69          66
#
#    2007-06-01  2007-07-01  2007-08-01  2007-09-01  2007-10-01  2007-11-01  \
# 0       10334        9440       11135       11275       10847       10810
# 1       11641       11183       13957       15709       15801       16020
# 2         915         930        1073        1204        1246        1275
# 3        2482        2318        2881        3407        3185        3238
# 4          82          65         147         157         159         164
#
# ...

# %%
df.set_index('Tipo da Equipe', inplace=True)

# %%
df.columns = pd.to_datetime(df.columns)

# %% [markdown]
# # visualizations

# %%
# Plotando o gráfico
plt.figure(figsize=(18, 6))

# Loop para plotar os gráficos
for equipe in df.index:
    plt.plot(df.columns, df.loc[equipe], label=equipe)

plt.xlabel('Ano')
plt.ylabel('Número de Equipes')
plt.title('Número de Equipes de Saúde por Tipo')
# plt.legend(loc = 'upper left', ncol =3)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
